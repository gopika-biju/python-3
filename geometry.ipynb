# %% [markdown]
# <a href="https://colab.research.google.com/github/gopika-biju/python-3/blob/main/geometry.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import geometry
a1=geometry.circle_area(8)
a2=geometry.rectangle_area(10,12)
a3=geometry.square_area(4)
print(a1,a2,a3)
# Out:
# 50.26548245743669 120 16
